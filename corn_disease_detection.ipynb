# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
dataset_path = ("C:\\Users\\AA.Y TRADEERS\\Downloads\\Corn_Disease_Detection\\images_data\\corn_disease_detection.ipynb")

# %%
print(os.getcwd())
# Out:
# c:\Users\AA.Y TRADEERS\Downloads\Corn_Disease_Detection

# %%
print(os.listdir())
# Out:
# ['.git', '.gitignore', '.venv', '.vscode', 'class_names.json', 'corn_disease_detection.ipynb', 'corn_disease_model.keras', 'images_data', 'images_data_backup', 'main.py', 'main_local.py', 'model.weights.h5', 'requirements.txt', '__pycache__']

# %%
import os

classes = os.listdir()

for class_name in classes:

  
    if os.path.isdir(class_name):

        total_images = len(os.listdir(class_name))

        print(class_name, ":", total_images)
# Out:
# .git : 10
# .venv : 6
# .vscode : 1
# images_data : 4
# images_data_backup : 4
# __pycache__ : 3

# %%
from PIL import Image

# %%
import os

healthy_images = os.listdir("C:\\Users\\AA.Y TRADEERS\\Downloads\\Corn_Disease_Detection\\images_data\\Healthy")

print(healthy_images[:10])
# Out:
# ['Corn_Health (1).jpg', 'Corn_Health (10).jpg', 'Corn_Health (100).jpg', 'Corn_Health (1000).jpg', 'Corn_Health (1001).jpg', 'Corn_Health (1002).jpg', 'Corn_Health (1003).jpg', 'Corn_Health (1004).jpg', 'Corn_Health (1005).jpg', 'Corn_Health (1006).jpg']

# %%
from PIL import Image

image_path = "C:\\Users\\AA.Y TRADEERS\\Downloads\\Corn_Disease_Detection\\images_data\\Healthy (1).jpg"

img = Image.open("C:\\Users\\AA.Y TRADEERS\\Downloads\\Corn_Disease_Detection\\images_data\\Healthy\\Corn_Health (1).jpg")

img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
print("Image Size:", img.size)
print("Image Width:", img.width)
print("Image Height:", img.height)
print("Image Format:", img.format)
print("Image Mode:", img.mode)
# Out:
# Image Size: (256, 256)
# Image Width: 256
# Image Height: 256
# Image Format: JPEG
# Image Mode: RGB

# %%
import numpy as np

image_array = np.array(img)

print(image_array.shape)
# Out:
# (256, 256, 3)

# %%
from PIL import Image
import os

sizes = set()

for folder in os.listdir("C:\\Users\\AA.Y TRADEERS\\Downloads\\Corn_Disease_Detection\\images_data"):
    folder_path = os.path.join("C:\\Users\\AA.Y TRADEERS\\Downloads\\Corn_Disease_Detection\\images_data", folder)

    if os.path.isdir(folder_path):
        for image_name in os.listdir(folder_path):
            image_path = os.path.join(folder_path, image_name)

            img = Image.open(image_path)
            sizes.add(img.size)

print(sizes)
# Out:
# {(378, 308), (432, 309), (349, 540), (417, 275), (300, 236), (400, 268), (694, 583), (852, 639), (388, 257), (1333, 1000), (563, 1122), (1500, 1125), (1440, 2560), (350, 230), (400, 487), (576, 1024), (2848, 4272), (200, 590), (550, 413), (1000, 750), (5184, 3456), (288, 419), (500, 375), (1080, 660), (313, 213), (1080, 614), (430, 359), (672, 832), (525, 395), (432, 679), (400, 263), (613, 700), (765, 257), (400, 272), (575, 188), (420, 378), (300, 386), (2273, 1901), (768, 1024), (310, 179), (550, 362), (527, 433), (299, 371), (392, 236), (580, 662), (1176, 781), (298, 372), (256, 256), (273, 400), (400, 267), (1200, 900), (765, 325), (432, 329), (600, 450), (412, 305), (224, 224), (600, 340), (1024, 768), (1275, 960), (1836, 3264), (675, 1200), (1054, 702), (743, 1591), (482, 378), (480, 360), (590, 393), (360, 242), (666, 443), (862, 882), (507, 297), (2761, 2027), (313, 386), (1200, 630), (690, 345), (1024, 681), (432, 324), (227, 300), (432, 287), (3264, 2448), (750, 350), (674
# ...

# %%
from PIL import Image
import os

corrupted_images = []

for folder in os.listdir("C:\\Users\\AA.Y TRADEERS\\Downloads\\Corn_Disease_Detection\\images_data"):

    folder_path = os.path.join("C:\\Users\\AA.Y TRADEERS\\Downloads\\Corn_Disease_Detection\\images_data", folder)

    if os.path.isdir(folder_path):

        for image_name in os.listdir(folder_path):

            image_path = os.path.join(folder_path, image_name)

            try:

                img = Image.open(image_path)

                img.verify()

            except:

                corrupted_images.append(image_path)

print("Total Corrupted Images:", len(corrupted_images))

print(corrupted_images)
# Out:
# Total Corrupted Images: 0
# []

# %%
folder_path = os.path.join("images_data", "Healthy")

# %%
import os
import random

from PIL import Image

import matplotlib.pyplot as plt

# %%
import os
import random
from PIL import Image
import matplotlib.pyplot as plt

healthy_folder = os.path.join("images_data","Healthy")

images = os.listdir(healthy_folder)

random_images = random.sample(images, 5)

plt.figure(figsize=(15,5))

for i, image_name in enumerate(random_images):

    image_path = os.path.join(healthy_folder, image_name)

    img = Image.open(image_path)

    plt.subplot(1,5,i+1)

    plt.imshow(img)

    plt.title(image_name)

    plt.axis("off")

plt.show()

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\AA.Y TRADEERS\Downloads\Corn_Disease_Detection

# %%
print(os.listdir())
# Out:
# ['.git', '.gitignore', '.venv', '.vscode', 'class_names.json', 'corn_disease_detection.ipynb', 'corn_disease_model.keras', 'images_data', 'images_data_backup', 'main.py', 'main_local.py', 'model.weights.h5', 'requirements.txt', '__pycache__']

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\AA.Y TRADEERS\Downloads\Corn_Disease_Detection

# %%
import os

print(os.listdir())
# Out:
# ['.git', '.gitignore', '.venv', '.vscode', 'class_names.json', 'corn_disease_detection.ipynb', 'corn_disease_model.keras', 'images_data', 'images_data_backup', 'main.py', 'main_local.py', 'model.weights.h5', 'requirements.txt', '__pycache__']

# %%
import os
import random
from PIL import Image
import matplotlib.pyplot as plt

def show_random_images(folder_name):

    folder_path = os.path.join("images_data", folder_name)

    images = os.listdir(folder_path)

    random_images = random.sample(images, 5)

    plt.figure(figsize=(15,5))

    for i, image_name in enumerate(random_images):

        image_path = os.path.join(folder_path, image_name)

        img = Image.open(image_path)

        plt.subplot(1,5,i+1)

        plt.imshow(img)

        plt.title(image_name, fontsize=8)

        plt.axis("off")

    plt.show()

# %%
show_random_images("Blight")

# %%
show_random_images("Healthy")

# %%
show_random_images("Common_Rust")

# %%
show_random_images("Gray_Leaf_Spot")

# %%
from PIL import Image
import os

dataset_path = "images_data"

rgb_count = 0
grayscale_count = 0

for folder in os.listdir(dataset_path):
    folder_path = os.path.join(dataset_path, folder)

    if os.path.isdir(folder_path):

        for image_name in os.listdir(folder_path):

            image_path = os.path.join(folder_path, image_name)

            try:
                img = Image.open(image_path)

                if img.mode == "RGB":
                    rgb_count += 1

                elif img.mode == "L":
                    grayscale_count += 1

            except:
                pass

print("RGB Images:", rgb_count)
print("Grayscale Images:", grayscale_count)
# Out:
# RGB Images: 4181
# Grayscale Images: 0

# %%
from collections import Counter
import os

dataset_path = "images_data"

extensions = Counter()

for folder in os.listdir(dataset_path):

    folder_path = os.path.join(dataset_path, folder)

    if os.path.isdir(folder_path):

        for image_name in os.listdir(folder_path):

            ext = os.path.splitext(image_name)[1].lower()

            extensions[ext] += 1

print(extensions)
# Out:
# Counter({'.jpg': 4185, '.jpeg': 1})

# %%
import os
import matplotlib.pyplot as plt

dataset_path = "images_data"

classes = []
counts = []

for folder in os.listdir(dataset_path):

    folder_path = os.path.join(dataset_path, folder)

    if os.path.isdir(folder_path):

        classes.append(folder)

        counts.append(len(os.listdir(folder_path)))

plt.figure(figsize=(8,5))

plt.bar(classes, counts)

plt.xlabel("Classes")

plt.ylabel("Number of Images")

plt.title("Dataset Distribution")

plt.show()

# %%
import os
import hashlib

dataset_path = "images_data"

hashes = {}
duplicates = []

for folder in os.listdir(dataset_path):

    folder_path = os.path.join(dataset_path, folder)

    if os.path.isdir(folder_path):

        for image_name in os.listdir(folder_path):

            image_path = os.path.join(folder_path, image_name)

            try:
                with open(image_path, "rb") as file:
                    file_hash = hashlib.md5(file.read()).hexdigest()

                if file_hash in hashes:
                    duplicates.append((hashes[file_hash], image_path))
                else:
                    hashes[file_hash] = image_path

            except Exception as e:
                print(f"Error reading {image_path}: {e}")

print(f"\nTotal Duplicate Images: {len(duplicates)}")

if duplicates:
    print("\nDuplicate Image Pairs:\n")
    for original, duplicate in duplicates:
        print("Original :", original)
        print("Duplicate:", duplicate)
        print("-" * 60)
else:
    print("No duplicate images found.")
# Out:
# Total Duplicate Images: 0
# No duplicate images found.

# %%
import os

files_to_delete = [
    r"images_data\Blight\Corn_Blight (77).jpg",
    r"images_data\Blight\Corn_Blight (1104).jpg"
]

for file_path in files_to_delete:
    if os.path.exists(file_path):
        os.remove(file_path)
        print(f"Deleted: {file_path}")
    else:
        print(f"File not found: {file_path}")

print("\nSelected duplicate images deleted successfully.")
# Out:
# File not found: images_data\Blight\Corn_Blight (77).jpg
# File not found: images_data\Blight\Corn_Blight (1104).jpg
#
# Selected duplicate images deleted successfully.

# %%
from PIL import Image
import os

sizes = set()

for folder in os.listdir("images_data"):
    folder_path = os.path.join("images_data", folder)

    if os.path.isdir(folder_path):
        for image_name in os.listdir(folder_path):
            image_path = os.path.join(folder_path, image_name)

            img = Image.open(image_path)
            sizes.add(img.size)

print(sizes)
# Out:
# {(378, 308), (432, 309), (349, 540), (417, 275), (300, 236), (400, 268), (694, 583), (852, 639), (388, 257), (1333, 1000), (563, 1122), (1500, 1125), (1440, 2560), (350, 230), (400, 487), (576, 1024), (2848, 4272), (200, 590), (550, 413), (1000, 750), (5184, 3456), (288, 419), (500, 375), (1080, 660), (313, 213), (1080, 614), (430, 359), (672, 832), (525, 395), (432, 679), (400, 263), (613, 700), (765, 257), (400, 272), (575, 188), (420, 378), (300, 386), (2273, 1901), (768, 1024), (310, 179), (550, 362), (527, 433), (299, 371), (392, 236), (580, 662), (1176, 781), (298, 372), (256, 256), (273, 400), (400, 267), (1200, 900), (765, 325), (432, 329), (600, 450), (412, 305), (224, 224), (600, 340), (1024, 768), (1275, 960), (1836, 3264), (675, 1200), (1054, 702), (743, 1591), (482, 378), (480, 360), (590, 393), (360, 242), (666, 443), (862, 882), (507, 297), (2761, 2027), (313, 386), (1200, 630), (690, 345), (1024, 681), (432, 324), (227, 300), (432, 287), (3264, 2448), (750, 350), (674
# ...

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# c:\Users\AA.Y TRADEERS\Downloads\Corn_Disease_Detection\.venv\Scripts\python.exe
# 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]

# %%
from PIL import Image
print("Pillow Installed Successfully")
# Out:
# Pillow Installed Successfully

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

print("TensorFlow:", tf.__version__)
print("NumPy:", np.__version__)
print("All libraries working!")
# Out:
# TensorFlow: 2.21.0
# NumPy: 2.5.1
# All libraries working!

# %%
import os

print(os.getcwd())
print(os.listdir())
print(os.listdir("images_data"))
# Out:
# c:\Users\AA.Y TRADEERS\Downloads\Corn_Disease_Detection
# ['.git', '.gitignore', '.venv', '.vscode', 'class_names.json', 'corn_disease_detection.ipynb', 'corn_disease_model.keras', 'images_data', 'images_data_backup', 'main.py', 'main_local.py', 'model.weights.h5', 'requirements.txt', '__pycache__']
# ['Blight', 'Common_Rust', 'Gray_Leaf_Spot', 'Healthy']

# %%
from PIL import Image

img = Image.open("images_data_backup/Common_Rust/Corn_Common_Rust (1275).jpg")
print(img.size)
# Out:
# (575, 188)

# %%
import shutil

source = "images_data_backup/Common_Rust/Corn_Common_Rust (1275).jpg"
destination = "images_data/Common_Rust/Corn_Common_Rust (1275).jpg"

shutil.copy(source, destination)

print("Image restored successfully.")
# Out:
# Image restored successfully.

# %%
from PIL import Image

img = Image.open("images_data/Common_Rust/Corn_Common_Rust (1275).jpg")
print(img.size)
# Out:
# (575, 188)

# %%
import tensorflow as tf

dataset = tf.keras.utils.image_dataset_from_directory(
    "images_data",
    image_size=(224, 224),
    batch_size=32,
    shuffle=True,
    seed=42
)

print(dataset.class_names)
# Out:
# Found 4186 files belonging to 4 classes.
# ['Blight', 'Common_Rust', 'Gray_Leaf_Spot', 'Healthy']

# %%
print(dataset.class_names)
# Out:
# ['Blight', 'Common_Rust', 'Gray_Leaf_Spot', 'Healthy']

# %%
for images, labels in dataset.take(1):
    print(images.shape)
    print(labels.shape)
# Out:
# (32, 224, 224, 3)
# (32,)

# %%
dataset = dataset.map(lambda x, y: (x / 255.0, y))

# %%
for images, labels in dataset.take(1):
    print(images[0].numpy().min())
    print(images[0].numpy().max())
# Out:
# 0.011764706
# 0.8901961

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

# %%
dataset_size = len(dataset)

train_size = int(0.7 * dataset_size)
val_size = int(0.15 * dataset_size)
test_size = dataset_size - train_size - val_size

train_dataset = dataset.take(train_size)

remaining = dataset.skip(train_size)

val_dataset = remaining.take(val_size)
test_dataset = remaining.skip(val_size)

print("Train Batches:", len(train_dataset))
print("Validation Batches:", len(val_dataset))
print("Test Batches:", len(test_dataset))
# Out:
# Train Batches: 91
# Validation Batches: 19
# Test Batches: 21

# %%
from tensorflow.keras import layers

data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.15),
    layers.RandomZoom(0.15),
])

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import (
    Input,
    Conv2D,
    MaxPooling2D,
    GlobalAveragePooling2D,
    Dense,
    Dropout,
    BatchNormalization
)

model = Sequential([

    Input(shape=(224,224,3)),

    data_augmentation,

    Conv2D(32,(3,3),activation="relu"),
    BatchNormalization(),
    MaxPooling2D(),

    Conv2D(64,(3,3),activation="relu"),
    BatchNormalization(),
    MaxPooling2D(),

    Conv2D(128,(3,3),activation="relu"),
    BatchNormalization(),
    MaxPooling2D(),

    GlobalAveragePooling2D(),

    Dense(256,activation="relu"),
    Dropout(0.5),

    Dense(4,activation="softmax")
])

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_2 (Sequential)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 222, 222, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=25,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/25
# c:\Users\AA.Y TRADEERS\Downloads\Corn_Disease_Detection\.venv\Lib\site-packages\keras\src\trainers\epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
# 38/91 ━━━━━━━━━━━━━━━━━━━━ 1:27 2s/step - accuracy: 0.7541 - loss: 0.6451
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 history = model.fit(
#       2     train_dataset,
#       3     validation_data=val_dataset,
#       4     epochs=25,
#
# File c:\Users\AA.Y TRADEERS\Downloads\Corn_Disease_Detection\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])

plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.legend(["Train", "Validation"])

plt.show()

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])

plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.legend(["Train", "Validation"])

plt.show()

# %%
test_loss, test_accuracy = model.evaluate(test_dataset)

print("Test Accuracy:", test_accuracy)
print("Test Loss:", test_loss)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 209ms/step - accuracy: 0.9294 - loss: 0.2044
# Test Accuracy: 0.9294294118881226
# Test Loss: 0.2044188529253006

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

# %%
actual_labels = []
predicted_labels = []

for images, labels in test_dataset:

    predictions = model.predict(images)

    predicted = np.argmax(predictions, axis=1)

    actual_labels.extend(labels.numpy())
    predicted_labels.extend(predicted)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step

# %%
from sklearn.metrics import classification_report

print(classification_report(actual_labels, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.90       179
#            1       0.98      0.96      0.97       192
#            2       0.89      0.71      0.79       101
#            3       1.00      1.00      1.00       194
#
#     accuracy                           0.94       666
#    macro avg       0.93      0.91      0.92       666
# weighted avg       0.94      0.94      0.93       666

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd

cm = confusion_matrix(actual_labels, predicted_labels)

print(pd.DataFrame(
    cm,
    index=["Blight","Common_Rust","Gray_Leaf_Spot","Healthy"],
    columns=["Blight","Common_Rust","Gray_Leaf_Spot","Healthy"]
))
# Out:
#                 Blight  Common_Rust  Gray_Leaf_Spot  Healthy
# Blight             173            1               5        0
# Common_Rust          4          184               4        0
# Gray_Leaf_Spot      27            2              72        0
# Healthy              0            0               0      194

# %%
class_names = [
    "Blight",
    "Common_Rust",
    "Gray_Leaf_Spot",
    "Healthy"
]

# %%
print(confusion_matrix(actual_labels, predicted_labels))
# Out:
# [[173   1   5   0]
#  [  4 184   4   0]
#  [ 27   2  72   0]
#  [  0   0   0 194]]

# %%
print(classification_report(
    actual_labels,
    predicted_labels,
    target_names=class_names
))
# Out:
#                 precision    recall  f1-score   support
#
#         Blight       0.85      0.97      0.90       179
#    Common_Rust       0.98      0.96      0.97       192
# Gray_Leaf_Spot       0.89      0.71      0.79       101
#        Healthy       1.00      1.00      1.00       194
#
#       accuracy                           0.94       666
#      macro avg       0.93      0.91      0.92       666
#   weighted avg       0.94      0.94      0.93       666

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# Classes
class_names = [
    "Blight",
    "Common_Rust",
    "Gray_Leaf_Spot",
    "Healthy"
   
]

# User se class ka naam lo
selected_class = input("Enter Class Name (Blight, Healthy, Gray_Leaf_Spot, Common_Rust): ")

# Check class
if selected_class not in class_names:
    print("Invalid Class Name!")

else:

    # Folder path
    folder_path = os.path.join("images_data", selected_class)

    # Random image
    image_name = random.choice(os.listdir(folder_path))

    # Complete path
    image_path = os.path.join(folder_path, image_name)

    # Load image
    img = image.load_img(image_path, target_size=(224,224))

    # Image to array
    img_array = image.img_to_array(img)

    # Batch dimension
    img_array = np.expand_dims(img_array, axis=0)

    # Normalize
    img_array = img_array / 255.0

    # Prediction
    prediction = model.predict(img_array, verbose=0)

    predicted_index = np.argmax(prediction)

    predicted_class = class_names[predicted_index]

    confidence = np.max(prediction) * 100

    # Show image
    plt.imshow(img)
    plt.axis("off")
    plt.title(f"Prediction: {predicted_class}")
    plt.show()

    print("Selected Class :", selected_class)
    print("Image Name     :", image_name)
    print("Predicted Class:", predicted_class)
    print(f"Confidence     : {confidence:.2f}%")

    if selected_class == predicted_class:
        print("✅ Prediction Correct")
    else:
        print("❌ Prediction Incorrect")
# Out:
# Selected Class : Gray_Leaf_Spot
# Image Name     : Corn_Gray_Spot (283).JPG
# Predicted Class: Healthy
# Confidence     : 64.70%
# ❌ Prediction Incorrect

# %%
model.save("corn_disease_model.keras")

print("Model Saved Successfully!")
# Out:
# Model Saved Successfully!

# %%
import json

class_names = [
    "Blight",
    "Common_Rust",
    "Gray_Leaf_Spot",
    "Healthy"
]

with open("class_names.json", "w") as f:
    json.dump(class_names, f)

print("Class Names Saved Successfully!")
# Out:
# Class Names Saved Successfully!

# %%
import tensorflow as tf

print(tf.__version__)

from tensorflow.keras.models import Sequential

print("TensorFlow Working")
# Out:
# 2.21.0
# TensorFlow Working

# %%
import os

model_path = "corn_disease_model.keras"

size_bytes = os.path.getsize(model_path)
size_mb = size_bytes / (1024 * 1024)

print(f"Model Size: {size_mb:.2f} MB")
# Out:
# Model Size: 1.54 MB

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 222, 222, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
import zipfile
import os

model_path = "corn_disease_model.keras"

with zipfile.ZipFile(model_path, "r") as z:
    print("Files inside model:")
    for info in z.infolist():
        size_mb = info.file_size / (1024 * 1024)
        print(f"{info.filename}: {size_mb:.2f} MB")

print("\nTotal file size:", os.path.getsize(model_path) / (1024 * 1024), "MB")
# Out:
# Files inside model:
# metadata.json: 0.00 MB
# config.json: 0.01 MB
# model.weights.h5: 1.52 MB
#
# Total file size: 1.5361328125 MB

# %%
import zipfile
import os
import h5py

model_path = "corn_disease_model.keras"
weights_path = "model.weights.h5"

# .keras file ke andar se weights file nikaalna
with zipfile.ZipFile(model_path, "r") as z:
    z.extract(weights_path, ".")

print("Weights file extracted successfully!")

# Ab HDF5 weights file ko open karein
with h5py.File(weights_path, "r") as f:
    print("\nContents of model.weights.h5:")

    def show_items(name, obj):
        if isinstance(obj, h5py.Dataset):
            size_mb = obj.size * obj.dtype.itemsize / (1024 * 1024)
            print(f"{name}: shape={obj.shape}, dtype={obj.dtype}, size={size_mb:.2f} MB")

    f.visititems(show_items)

print("\nWeights file size:",
      os.path.getsize(weights_path) / (1024 * 1024), "MB")
# Out:
# Weights file extracted successfully!
#
# Contents of model.weights.h5:
# layers/batch_normalization/vars/0: shape=(32,), dtype=float32, size=0.00 MB
# layers/batch_normalization/vars/1: shape=(32,), dtype=float32, size=0.00 MB
# layers/batch_normalization/vars/2: shape=(32,), dtype=float32, size=0.00 MB
# layers/batch_normalization/vars/3: shape=(32,), dtype=float32, size=0.00 MB
# layers/batch_normalization_1/vars/0: shape=(64,), dtype=float32, size=0.00 MB
# layers/batch_normalization_1/vars/1: shape=(64,), dtype=float32, size=0.00 MB
# layers/batch_normalization_1/vars/2: shape=(64,), dtype=float32, size=0.00 MB
# layers/batch_normalization_1/vars/3: shape=(64,), dtype=float32, size=0.00 MB
# layers/batch_normalization_2/vars/0: shape=(128,), dtype=float32, size=0.00 MB
# layers/batch_normalization_2/vars/1: shape=(128,), dtype=float32, size=0.00 MB
# layers/batch_normalization_2/vars/2: shape=(128,), dtype=float32, size=0.00 MB
# ...

# %%
import os

size_mb = os.path.getsize("corn_disease_model.keras") / (1024 * 1024)

print(f"New Model Size: {size_mb:.2f} MB")
# Out:
# New Model Size: 1.54 MB

# %%
model.save("corn_disease_model.keras")

print("Model Saved Successfully!")
# Out:
# Model Saved Successfully!
